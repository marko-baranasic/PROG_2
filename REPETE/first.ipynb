# %%
n1 = 100.2

if(n1.isdecimal()):
    print(n1)
else:
    print("Not a number")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 n1 = 100.2
# ----> 3 if(n1.isdecimal()):
#       4     print(n1)
#       5 else:
#
# AttributeError: 'float' object has no attribute 'isdecimal'

# %%
try:
#    n1 = float(input("Enter the first number: "))
#    n2 = float(input("Enter the second number: "))
   

except ValueError:
    print("Greška: molim unesi samo brojeve.")
# Out:
#   Cell In[30], line 6
#     except ValueError:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1
